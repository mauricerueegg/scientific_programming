# %% [markdown]
# # Getting all available Swiss petrol stations using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import json
import folium
import requests
import pandas as pd

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Show current working directory
print(os.getcwd())
# Out:
# /Users/mauriceruegg/Documents/ZHAW_lokal/4_Semester/Scientific_Prototyping/scientific_programming/Week_04/challenge

# %% [markdown]
# ## Overpass turbo query to get available petrol stations

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["amenity"="fuel"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to .json file
with open('petrol_stations.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = pd.json_normalize(data)
df.head()
# Out:
#    type       id        lat       lon tags.amenity  \
# 0  node   734402  46.690599  7.668189         fuel
# 1  node  1228781  46.878598  7.542326         fuel
# 2  node  5702030  46.680546  7.827412         fuel
# 3  node  5702071  46.683415  7.844559         fuel
# 4  node  8082505  46.683817  7.664427         fuel
#
#                                           tags.fixme tags.name tags.operator  \
# 0  Please check name and brand. Agip becomes Eni....      Agip          Agip
# 1                                                NaN       NaN            BP
# 2                                                NaN    Migrol           NaN
# 3                                                NaN      Avia          Avia
# 4                                                NaN       NaN           NaN
#
#   tags.brand tags.fuel:diesel  ... tags.fuel:octane_87  \
# 0        NaN              NaN  ...                 NaN
# 1         BP              yes  ...                 NaN
# 2        NaN              NaN  ...                 NaN
# 3       Avia              NaN  ...                 NaN
# 4        NaN              NaN  ...                 NaN
#
#   tags.fuel:Shell_V-Power tags.payment:post_finance tags.covered  \
# 0                     NaN                       NaN          NaN
# 1                     NaN                       NaN          NaN
# 2                     NaN                       NaN          NaN
# 3                     NaN                       NaN          NaN
# 4                     NaN                       NaN          NaN
#
#   tags.payment:girocard tags.payment:vpay tags.fuel:diesel_plus  \
# 0                   NaN               NaN                   NaN
# 1                   NaN               NaN                   NaN
# 2                   NaN               NaN                   NaN
# 3                   NaN               NaN                   NaN
# 4                   NaN               NaN                   NaN
#
#   tags.construction tags.dog tags.payment:hubrol_card
# 0               NaN      NaN                      NaN
# 1               NaN      NaN                      NaN
# 2               NaN      NaN                      NaN
# 3               NaN      NaN                      NaN
# 4               NaN      NaN                      NaN
#
# [5 rows x 191 columns]

# %% [markdown]
# ## Save data frame to a .csv file

# %%
# Write data frame to .csv - file
df.to_csv('petrol-stations.csv', index=False, sep=";", encoding='utf-8')

# %% [markdown]
# ## Use a pivot table to count the number of petrol stations per operator

# %%
# Create pivot table
tab = pd.pivot_table(df[['id', 'tags.name']], 
                       values=['id'], 
                       index=['tags.name'],
                       aggfunc='count')

# Sort pivot table
tab_sorted = tab.sort_values(by=['id'], ascending=False)
tab_sorted
# Out:
#                          id
# tags.name
# Avia                    162
# Agrola                  148
# BP                      110
# Tamoil                   97
# Shell                    77
# ...                     ...
# Garage du Clos            1
# Garage du Gros-de-Vaud    1
# Garage du Nord            1
# Garage du Port            1
# villoel                   1
#
# [803 rows x 1 columns]

# %% [markdown]
# ## Plot petrol stations on map

# %%
# Subset of petrol stations by brand
locations = df[["lat", 
                "lon", 
                "tags.brand", 
                "tags.shop"]].loc[df["tags.brand"].isin(['Migrol', 
                                                         'Agip', 
                                                         'Shell'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                   popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#           lat       lon tags.brand tags.shop
# 8   47.686119  8.621418      Shell       NaN
# 19  47.495696  8.712981      Shell       NaN
# 23  47.381593  8.509545      Shell       NaN
# 28  47.381110  8.492148     Migrol       NaN
# 32  47.337432  8.530242      Shell       NaN
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa32996a55a10b362bbcc6ecc09c2b4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa32996a55a10b362bbcc6ecc09c2b4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa32996a55a10b362bbcc6ecc09c2b4c = L.map(
#                 &quot;map_fa32996a55a10b362bbcc6ecc09c2b4c&quot;,
#                 {
#                     center: [47.071460446176474, 8.129561144705882],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_fa32996a55a10b362bbcc6ecc09c2b4c);
#
#
#
#
#
#             var tile_layer_9a1a3e8471a5d01910146ef1ce10a44f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9a1a3e8471a5d01910146ef1ce10a44f.addTo(map_fa32996a55a10b362bbcc6ecc09c2b4c);
#
#
#             var marker_15bf4a8f47d1de3841fc5b09a6d38adf = L.marker(
#                 [47.686119, 8.621418],
#                 {}
#             ).addTo(map_fa32996a55a10b362bbcc6ecc09c2b4c);
#
#
#         var popup_27d3d0479f6cb2e19d61b62cda87e7b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4dcc3060039e6e20ce3d1a6e02eea2ef = $(`&lt;div id=&quot;html_4dcc3060039e6e20ce3d1a6e02eea2ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_27d3d0479f6cb2e19d61b62cda87e7b7.setContent(html_4dcc3060039e6e20ce3d1a6e02eea2ef);
#
#
#
#         marker_15bf4a8f47d1de3841fc5b09a6d38adf.bindPopup(popup_27d3d0479f6cb2e19d61b62cda87e7b7)
#         ;
#
#
#
#
#             var marker_9f7b2a3aae7810446ed1efc7a367e4f7 = L.marker(
#                 [47.4956958, 8.7129812],
#                 {}
#             ).addTo(map_fa32996a55a10b362bbcc6ecc09c2b4c);
#
#
#         var popup_ba32f681b40cabe630edaf9734e8bc0f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a56a41560eb8d1f83d562a25a41a8f5c = $(`&lt;div id=&quot;html_a56a41560eb8d1f83d562a25a41a8f5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_ba32f681b40cabe630edaf9734e8bc0f.setContent(html_a56a41560eb8d1f83d562a25a41a8f5c);
#
#
#
#         marker_9f7b2a3aae7810446ed1efc7a367e4f7.bindPopup(popup_ba32f681b40cabe630edaf9734e8bc0f)
#         ;
#
#
#
#
#             var marker_abb72f9d9008c8895bc87197e3aa801d = L.marker(
#                 [47.3815928, 8.5095448],
#                 {}
#             ).addTo(map_fa32996a55a10b362bbcc6ecc09c2b4c);
#
#
#         var popup_5fb6064293dc5776713310a83ba09d75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8fbb29e88fc1e97a7b80a4cb472fd828 = $(`&lt;div id=&quot;html_8fbb29e88fc1e97a7b80a4cb472fd828&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_5fb6064293dc5776713310a83ba09d75.setContent(html_8fbb29e88fc1e97a7b80a4cb472fd828);
#
#
#
#         marker_abb72f9d9008c8895bc87197e3aa801d.bindPopup(popup_5fb6064293dc5776713310a83ba09d75)
#         ;
#
#
#
#
#             var marker_6d6ea178f9e6f0c295c8a160bd53034f = L.marker(
#                 [47.3811098, 8.4921479],
#                 {}
#             ).addTo(map_fa32996a55a10b362bbcc6ecc09c2b4c);
#
#
#         var popup_c4127b016333e9951b48264c2b386145 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6f5a52ed884c20c87e7d58a8d044af25 = $(`&lt;div id=&quot;html_6f5a52ed884c20c87e7d58a8d044af25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migrol&lt;/div&gt;`)[0];
#                 popup_c4127b016333e9951b48264c2b386145.setContent(html_6f5a52ed884c20c87e7d58a8d044af25);
#
#
#
#         marker_6d6ea178f9e6f0c295c8a160bd53034f.bindPopup(popup_c4127b016333e9951b48264c2b386145)
#         ;
#
#
#
#
#             var marker_4a95d218a3d8869e356e29ea316cafed = L.marker(
#                 [47.3374315, 8.5302419],
#                 {}
#             ).addTo(map_fa32996a55a10b362bbcc6ecc09c2b4c);
#
#
#         var popup_d660b8c382ce6abec5460e2b32b2edd6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_844c95fb21c0f08dfc45947d1b68b475 = $(`&lt;div id=&quot;html_844c95fb21c0f08dfc45947d1b68b475&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_d660b8c382ce6abec5460e2b32b2edd6.setContent(html_844c95fb21c0f08dfc45947d1b68b475);
#
#
#
#         marker_4a95d218a3d8869e356e29ea316cafed.bindPopup(popup_d660b8c382ce6abec5460e2b32b2edd6)
#         ;
#
#
#
#
#             var marker_1b4921d48cb062165a2003367b906bad = L.marker(
#                 [47.0265599, 8.2991398],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Darwin | 23.2.0
# Datetime: 2024-03-20 16:05:32
# Python Version: 3.10.13
# -----------------------------------
